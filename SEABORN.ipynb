# %%
import seaborn as sns
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12364/2813024729.py in <module>
# ----> 1 import seaborn as sns
#       2 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\User\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline 
# #This  above line gives the plot after exceution

# %%
sns.set(style="darkgrid")

# %%
tips=sns.load_dataset("tips")
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(x="total_bill",y="tip",data=tips)

# %%
dir(sns.FacetGrid)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bottom_axes',
#  '_facet_color',
#  '_facet_plot',
#  '_finalize_grid',
#  '_get_palette',
#  '_inner_axes',
#  '_left_axes',
#  '_legend_out',
#  '_margin_titles',
#  '_not_bottom_axes',
#  '_not_left_axes',
#  '_update_legend_data',
#  'add_legend',
#  'ax',
#  'axes',
#  'axes_dict',
#  'despine',
#  'facet_axis',
#  'facet_data',
#  'fig',
#  'figure',
#  'legend',
#  'map',
#  'map_dataframe',
#  'refline',
#  'savefig',
#  'set',
#  'set_axis_labels',
#  'set_titles',
#  'set_xlabels',
#  'set_xticklabels',
#  'set_ylabels',
#  'set_yticklabels',
# ...

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="sex")

# %% [markdown]
# # knowing the count of  smokers

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker")

# %% [markdown]
# # knowing the count of size

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="size")

# %% [markdown]
# # knowing the count of day

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="day")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker",style='time')

# %%
hue: chages the colour
style: changes the style of representation
size: changes the size

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker",size="size",style="time")
