# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.4.1

# %% [raw]
#  a data set is a collection of data(Tabular format)

# %% [markdown]
# ## creating the dataFrame

# %% [markdown]
# In python we have to give 2 backward slashes in loaction.If we give only 1 slash it consider as a constant

# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\User\\Desktop\\Data.csv") 
df=pd.DataFrame(d) #D and F should be captial

# %%
df
# Out:
#      season episode_num_in_season  episode_num_overall               title  \
# 0         1                     1                    1       Pilot: Part 1
# 1         1                     2                    2       Pilot: Part 2
# 2         1                     3                    3         Tabula Rasa
# 3         1                     4                    4           Walkabout
# 4         1                     5                    5        White Rabbit
# ..      ...                   ...                  ...                 ...
# 116       6                    14                  117       The Candidate
# 117       6                    15                  118      Across the Sea
# 118       6                    16                  119  What They Died For
# 119       6                    17                  120             The End
# 120       6                    18                  121      The End Part 2
#
# ...

# %% [markdown]
# # creating Data Frame using dict()

# %%
di={"Name":["sathya","Vardhan","Reddy"],"Roll_NO":[1,2,3],"percentage":[95,96,97]}

# %%
di
# Out:
# {'Name': ['sathya', 'Vardhan', 'Reddy'],
#  'Roll_NO': [1, 2, 3],
#  'percentage': [95, 96, 97]}

# %%
df=pd.DataFrame(di) # It gives the   indexing , when data is converted into data frame
df
# Out:
#       Name  Roll_NO  percentage
# 0   sathya        1          95
# 1  Vardhan        2          96
# 2    Reddy        3          97

# %% [markdown]
# ## Creating a data Frame using list

# %%
l=[("abc",12,12),("def",13,14),("ghi",15,16,17)]

# %%
l
# Out:
# [('abc', 12, 12), ('def', 13, 14), ('ghi', 15, 16, 17)]

# %%
df=pd.DataFrame(l)

# %%
df
# Out:
#      0   1   2     3
# 0  abc  12  12   NaN
# 1  def  13  14   NaN
# 2  ghi  15  16  17.0

# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\User\\Desktop\\Data.csv") 
df=pd.DataFrame(d) #D and F should be captial

# %%
df
# Out:
#      season episode_num_in_season  episode_num_overall               title  \
# 0         1                     1                    1       Pilot: Part 1
# 1         1                     2                    2       Pilot: Part 2
# 2         1                     3                    3         Tabula Rasa
# 3         1                     4                    4           Walkabout
# 4         1                     5                    5        White Rabbit
# ..      ...                   ...                  ...                 ...
# 116       6                    14                  117       The Candidate
# 117       6                    15                  118      Across the Sea
# 118       6                    16                  119  What They Died For
# 119       6                    17                  120             The End
# 120       6                    18                  121      The End Part 2
#
# ...

# %%
df.head() # It gives the 5  indexes by default
# Out:
#    season episode_num_in_season  episode_num_overall          title  \
# 0       1                     1                    1  Pilot: Part 1
# 1       1                     2                    2  Pilot: Part 2
# 2       1                     3                    3    Tabula Rasa
# 3       1                     4                    4      Walkabout
# 4       1                     5                    5   White Rabbit
#
#     directed_by                                         written_by  \
# 0  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 1  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 2   Jack Bender                                     Damon Lindelof
# 3   Jack Bender                                         David Fury
# 4   Kevin Hooks                                   Christian Taylor
#
#   featured_character original_air_date  us_viewers
# 0               Jack        22-09-2004    18650000
# ...

# %%
df.head(2) # It gives upto 2 indexes
# Out:
#    season episode_num_in_season  episode_num_overall          title  \
# 0       1                     1                    1  Pilot: Part 1
# 1       1                     2                    2  Pilot: Part 2
#
#     directed_by                                         written_by  \
# 0  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 1  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
#
#   featured_character original_air_date  us_viewers
# 0               Jack        22-09-2004    18650000
# 1     Charlie & Kate        29-09-2004    17000000

# %%
df.head(12)  ## It gives upto 12 indexes
# Out:
#     season episode_num_in_season  episode_num_overall  \
# 0        1                     1                    1
# 1        1                     2                    2
# 2        1                     3                    3
# 3        1                     4                    4
# 4        1                     5                    5
# 5        1                     6                    6
# 6        1                     7                    7
# 7        1                     8                    8
# 8        1                     9                    9
# 9        1                    10                   10
# 10       1                    11                   11
# 11       1                    12                   12
#
#                                      title       directed_by  \
# 0                            Pilot: Part 1      J. J. Abrams
# 1                            Pilot: Part 2      J. J. Abrams
# 2                              Tabula Rasa       Jack Bender
# ...

# %%
df.tail() # It gives the last 5 indexes values
# Out:
#      season episode_num_in_season  episode_num_overall               title  \
# 116       6                    14                  117       The Candidate
# 117       6                    15                  118      Across the Sea
# 118       6                    16                  119  What They Died For
# 119       6                    17                  120             The End
# 120       6                    18                  121      The End Part 2
#
#       directed_by                                         written_by  \
# 116   Jack Bender                    Elizabeth Sarnoff & Jim Galasso
# 117  Tucker Gates                      Carlton Cuse & Damon Lindelof
# 118  Paul Edwards  Edward Kitsis & Adam Horowitz & Elizabeth Sarnoff
# 119   Jack Bender                      Damon Lindelof & Carlton Cuse
# 120   Jack Bender                      Damon Lindelof & Carlton Cuse
#
#        featured_character original_air_date  us_viewers
# ...

# %%
df.tail(1) # it gives the last index row
# Out:
#      season episode_num_in_season  episode_num_overall           title  \
# 120       6                    18                  121  The End Part 2
#
#      directed_by                     written_by featured_character  \
# 120  Jack Bender  Damon Lindelof & Carlton Cuse            various
#
#     original_air_date  us_viewers
# 120        23-05-2010    13570000

# %%
df.describe() # it gives all mathematical values
# Out:
#            season  episode_num_overall    us_viewers
# count  121.000000           121.000000  1.210000e+02
# mean     3.231405            61.000000  1.458099e+07
# std      1.735705            35.073732  4.051805e+06
# min      1.000000             1.000000  8.290000e+06
# 25%      2.000000            31.000000  1.127000e+07
# 50%      3.000000            61.000000  1.362000e+07
# 75%      5.000000            91.000000  1.784000e+07
# max      6.000000           121.000000  2.347000e+07

# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\User\\Desktop\\Data.csv") 
df=pd.DataFrame(d) #D and F should be captial

# %%
df
# Out:
#      season episode_num_in_season  episode_num_overall               title  \
# 0         1                     1                    1       Pilot: Part 1
# 1         1                     2                    2       Pilot: Part 2
# 2         1                     3                    3         Tabula Rasa
# 3         1                     4                    4           Walkabout
# 4         1                     5                    5        White Rabbit
# ..      ...                   ...                  ...                 ...
# 116       6                    14                  117       The Candidate
# 117       6                    15                  118      Across the Sea
# 118       6                    16                  119  What They Died For
# 119       6                    17                  120             The End
# 120       6                    18                  121      The End Part 2
#
# ...

# %%
df.shape # It gives rows follwed by columns
# Out:
# (121, 9)

# %% [markdown]
# # df[start:stop:step]

# %%
df[1:10:2] # start index is 0 , stop index is 10 and step size is 2
# Out:
#    season episode_num_in_season  episode_num_overall                    title  \
# 1       1                     2                    2            Pilot: Part 2
# 3       1                     4                    4                Walkabout
# 5       1                     6                    6  House of the Rising Sun
# 7       1                     8                    8           Confidence Man
# 9       1                    10                   10        Raised by Another
#
#        directed_by                                         written_by  \
# 1     J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 3      Jack Bender                                         David Fury
# 5  Michael Zinberg                             Javier Grillo-Marxuach
# 7     Tucker Gates                                     Damon Lindelof
# 9   Marita Grabiak                                      Lynne E. Litt
#
#   featured_character original_air_date  us_viewers
# ...

# %% [markdown]
# # accessing through column name

# %%
df["title"]
# Out:
# 0           Pilot: Part 1
# 1           Pilot: Part 2
# 2             Tabula Rasa
# 3               Walkabout
# 4            White Rabbit
#               ...
# 116         The Candidate
# 117        Across the Sea
# 118    What They Died For
# 119               The End
# 120        The End Part 2
# Name: title, Length: 121, dtype: object

# %%
df[["title","directed_by"]]  #Accessing the 2 coln names
# Out:
#                   title   directed_by
# 0         Pilot: Part 1  J. J. Abrams
# 1         Pilot: Part 2  J. J. Abrams
# 2           Tabula Rasa   Jack Bender
# 3             Walkabout   Jack Bender
# 4          White Rabbit   Kevin Hooks
# ..                  ...           ...
# 116       The Candidate   Jack Bender
# 117      Across the Sea  Tucker Gates
# 118  What They Died For  Paul Edwards
# 119             The End   Jack Bender
# 120      The End Part 2   Jack Bender
#
# [121 rows x 2 columns]

# %% [markdown]
# # df[[]"c1_nam1","c2_name"]][start:stop:step]

# %%
df[["title","directed_by"]][1:10:2]
# Out:
#                      title      directed_by
# 1            Pilot: Part 2     J. J. Abrams
# 3                Walkabout      Jack Bender
# 5  House of the Rising Sun  Michael Zinberg
# 7           Confidence Man     Tucker Gates
# 9        Raised by Another   Marita Grabiak

# %%
for i in df.iterrows(): # it prints the  single row wise
    print(i)
# Out:
# (0, season                                                                   1
# episode_num_in_season                                                    1
# episode_num_overall                                                      1
# title                                                        Pilot: Part 1
# directed_by                                                   J. J. Abrams
# written_by               Story by: Jeffrey Lieber and J. J. Abrams & Da...
# featured_character                                                    Jack
# original_air_date                                               22-09-2004
# us_viewers                                                        18650000
# Name: 0, dtype: object)
# (1, season                                                                   1
# episode_num_in_season                                                    2
# episode_num_overall                                                      2
# ...

# %% [markdown]
# # loc &iloc

# %%
df.loc[1] # it gives the information about index 1 row wiswe data
# Out:
# season                                                                   1
# episode_num_in_season                                                    2
# episode_num_overall                                                      2
# title                                                        Pilot: Part 2
# directed_by                                                   J. J. Abrams
# written_by               Story by: Jeffrey Lieber and J. J. Abrams & Da...
# featured_character                                          Charlie & Kate
# original_air_date                                               29-09-2004
# us_viewers                                                        17000000
# Name: 1, dtype: object

# %%
df.loc[1,["title"]] # It gives the information of title of 1st row
# Out:
# title    Pilot: Part 2
# Name: 1, dtype: object

# %%
df.loc[1,["title","us_viewers"]] #
# Out:
# title         Pilot: Part 2
# us_viewers         17000000
# Name: 1, dtype: object

# %%
df.loc[0:5] # In loc both start and stop index are included
# Out:
#    season episode_num_in_season  episode_num_overall                    title  \
# 0       1                     1                    1            Pilot: Part 1
# 1       1                     2                    2            Pilot: Part 2
# 2       1                     3                    3              Tabula Rasa
# 3       1                     4                    4                Walkabout
# 4       1                     5                    5             White Rabbit
# 5       1                     6                    6  House of the Rising Sun
#
#        directed_by                                         written_by  \
# 0     J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 1     J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 2      Jack Bender                                     Damon Lindelof
# 3      Jack Bender                                         David Fury
# 4      Kevin Hooks                                   Christian Taylor
# ...

# %%
df.iloc[0:5] # In iloc stop index is not included
# Out:
#    season episode_num_in_season  episode_num_overall          title  \
# 0       1                     1                    1  Pilot: Part 1
# 1       1                     2                    2  Pilot: Part 2
# 2       1                     3                    3    Tabula Rasa
# 3       1                     4                    4      Walkabout
# 4       1                     5                    5   White Rabbit
#
#     directed_by                                         written_by  \
# 0  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 1  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 2   Jack Bender                                     Damon Lindelof
# 3   Jack Bender                                         David Fury
# 4   Kevin Hooks                                   Christian Taylor
#
#   featured_character original_air_date  us_viewers
# 0               Jack        22-09-2004    18650000
# ...

# %%
df.loc[0:5,"title"]
# Out:
# 0              Pilot: Part 1
# 1              Pilot: Part 2
# 2                Tabula Rasa
# 3                  Walkabout
# 4               White Rabbit
# 5    House of the Rising Sun
# Name: title, dtype: object

# %%
df.loc[0:5,["title","written_by"]]
# Out:
#                      title                                         written_by
# 0            Pilot: Part 1  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 1            Pilot: Part 2  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 2              Tabula Rasa                                     Damon Lindelof
# 3                Walkabout                                         David Fury
# 4             White Rabbit                                   Christian Taylor
# 5  House of the Rising Sun                             Javier Grillo-Marxuach

# %%
df.loc[0:5]
# Out:
#    season episode_num_in_season  episode_num_overall                    title  \
# 0       1                     1                    1            Pilot: Part 1
# 1       1                     2                    2            Pilot: Part 2
# 2       1                     3                    3              Tabula Rasa
# 3       1                     4                    4                Walkabout
# 4       1                     5                    5             White Rabbit
# 5       1                     6                    6  House of the Rising Sun
#
#        directed_by                                         written_by  \
# 0     J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 1     J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 2      Jack Bender                                     Damon Lindelof
# 3      Jack Bender                                         David Fury
# 4      Kevin Hooks                                   Christian Taylor
# ...

# %%
df.loc[::-1]
# Out:
#      season episode_num_in_season  episode_num_overall               title  \
# 120       6                    18                  121      The End Part 2
# 119       6                    17                  120             The End
# 118       6                    16                  119  What They Died For
# 117       6                    15                  118      Across the Sea
# 116       6                    14                  117       The Candidate
# ..      ...                   ...                  ...                 ...
# 4         1                     5                    5        White Rabbit
# 3         1                     4                    4           Walkabout
# 2         1                     3                    3         Tabula Rasa
# 1         1                     2                    2       Pilot: Part 2
# 0         1                     1                    1       Pilot: Part 1
#
# ...

# %% [markdown]
# # df.[row_stop:row_stop,coln_stop:coln_stop]

# %%
df.iloc[0:4,0:6]
# Out:
#    season episode_num_in_season  episode_num_overall          title  \
# 0       1                     1                    1  Pilot: Part 1
# 1       1                     2                    2  Pilot: Part 2
# 2       1                     3                    3    Tabula Rasa
# 3       1                     4                    4      Walkabout
#
#     directed_by                                         written_by
# 0  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 1  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 2   Jack Bender                                     Damon Lindelof
# 3   Jack Bender                                         David Fury

# %%
df.iloc[0:4]
# Out:
#    season episode_num_in_season  episode_num_overall          title  \
# 0       1                     1                    1  Pilot: Part 1
# 1       1                     2                    2  Pilot: Part 2
# 2       1                     3                    3    Tabula Rasa
# 3       1                     4                    4      Walkabout
#
#     directed_by                                         written_by  \
# 0  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 1  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 2   Jack Bender                                     Damon Lindelof
# 3   Jack Bender                                         David Fury
#
#   featured_character original_air_date  us_viewers
# 0               Jack        22-09-2004    18650000
# 1     Charlie & Kate        29-09-2004    17000000
# 2               Kate        06-10-2004    16540000
# 3              Locke        13-10-2004    18160000

# %%
df.iloc[2,4] # it gives the 2nd row 4th element
# Out:
# 'Jack Bender'

# %%
df.iloc[[0:4,1]
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_18700/156776629.py", line 1
#     df.iloc[[0:4,1]
#               ^
# SyntaxError: invalid syntax

# %%
df.iloc[[1,2,3,7]] #It gives the list of  given rows
# Out:
#    season episode_num_in_season  episode_num_overall           title  \
# 1       1                     2                    2   Pilot: Part 2
# 2       1                     3                    3     Tabula Rasa
# 3       1                     4                    4       Walkabout
# 7       1                     8                    8  Confidence Man
#
#     directed_by                                         written_by  \
# 1  J. J. Abrams  Story by: Jeffrey Lieber and J. J. Abrams & Da...
# 2   Jack Bender                                     Damon Lindelof
# 3   Jack Bender                                         David Fury
# 7  Tucker Gates                                     Damon Lindelof
#
#   featured_character original_air_date  us_viewers
# 1     Charlie & Kate        29-09-2004    17000000
# 2               Kate        06-10-2004    16540000
# 3              Locke        13-10-2004    18160000
# 7             Sawyer        10-11-2004    18440000

# %%
df.iloc[[1,2,3,7],8] # it gives the 8Th colunm elements of  rows 1,2,3,7
# Out:
# 1    17000000
# 2    16540000
# 3    18160000
# 7    18440000
# Name: us_viewers, dtype: int64

# %%
 df.iloc[:,[1,2,3,4]] # It prints only coln:1,2,3,4 of all rows.
# Out:
#     episode_num_in_season  episode_num_overall               title  \
# 0                       1                    1       Pilot: Part 1
# 1                       2                    2       Pilot: Part 2
# 2                       3                    3         Tabula Rasa
# 3                       4                    4           Walkabout
# 4                       5                    5        White Rabbit
# ..                    ...                  ...                 ...
# 116                    14                  117       The Candidate
# 117                    15                  118      Across the Sea
# 118                    16                  119  What They Died For
# 119                    17                  120             The End
# 120                    18                  121      The End Part 2
#
#       directed_by
# 0    J. J. Abrams
# 1    J. J. Abrams
# 2     Jack Bender
# 3     Jack Bender
# 4     Kevin Hooks
# ..            ...
# 116   Jack Bender
# ...

# %%
df.iloc[1:7:2,[1,2,3]] # Start stop and index,and  colun no to be printed
# Out:
#   episode_num_in_season  episode_num_overall                    title
# 1                     2                    2            Pilot: Part 2
# 3                     4                    4                Walkabout
# 5                     6                    6  House of the Rising Sun

# %% [raw]
# # in loc stop index also gets included, in iloc stop index will no to be included

# %% [raw]
#  in loc we represent by" COLN NAME "in ILOC we represent  by "COLN NUMBER"

# %%
df.sort_values("us_viewers") # It sorts  the coln "us_viewers" in accending order and least value row will be placed in 
                            #first place
# Out:
#      season episode_num_in_season  episode_num_overall  \
# 97        5                    12                   98
# 100       5                    15                  101
# 95        5                    10                   96
# 110       6                     8                  111
# 99        5                    14                  100
# ..      ...                   ...                  ...
# 28        2                     4                   29
# 31        2                     7                   32
# 27        2                     3                   28
# 26        2                     2                   27
# 25        2                     1                   26
#
#                             title       directed_by  \
# 97                   Dead Is Dead  Stephen Williams
# 100             Follow the Leader  Stephen Williams
# 95                   He's Our You     Greg Yaitanes
# 110                         Recon       Jack Bender
# ...

# %%
 # to sort in decending order, we have to  make ascending ="false "because  sorting is in ascending by defalut

# %%
df.sort_values("us_viewers",ascending=False) # it gives in decending order
# Out:
#      season episode_num_in_season  episode_num_overall  \
# 25        2                     1                   26
# 26        2                     2                   27
# 27        2                     3                   28
# 31        2                     7                   32
# 28        2                     4                   29
# ..      ...                   ...                  ...
# 99        5                    14                  100
# 110       6                     8                  111
# 95        5                    10                   96
# 100       5                    15                  101
# 97        5                    12                   98
#
#                             title       directed_by  \
# 25   Man of Science, Man of Faith       Jack Bender
# 26                         Adrift  Stephen Williams
# 27                    Orientation       Jack Bender
# 31              The Other 48 Days   Eric Laneuville
# ...

# %%
df.sort_values("written_by") # it sorts in alphabetical order
# Out:
#     season episode_num_in_season  episode_num_overall  \
# 53       3                     5                   54
# 80       4                     9                   81
# 97       5                    12                   98
# 89       5                     4                   90
# 84       4                    13                   85
# ..     ...                   ...                  ...
# 43       2                    19                   44
# 49       3                     1                   50
# 21       1                    22                   22
# 1        1                     2                    2
# 0        1                     1                    1
#
#                                  title       directed_by  \
# 53                  The Cost of Living       Jack Bender
# 80         The Shape of Things to Come       Jack Bender
# 97                        Dead Is Dead  Stephen Williams
# 89                   The Little Prince  Stephen Williams
# ...

# %%
df.sort_values(["episode_num_in_season","episode_num_overall"]) # It sorts based on two columns ,it gives 1st priority to coln 1
# Out:
#      season episode_num_in_season  episode_num_overall  \
# 0         1                     1                    1
# 25        2                     1                   26
# 49        3                     1                   50
# 72        4                     1                   73
# 86        5                     1                   87
# ..      ...                   ...                  ...
# 33        2                     9                   34
# 57        3                     9                   58
# 80        4                     9                   81
# 94        5                     9                   95
# 111       6                     9                  112
#
#                             title       directed_by  \
# 0                   Pilot: Part 1      J. J. Abrams
# 25   Man of Science, Man of Faith       Jack Bender
# 49           A Tale of Two Cities       Jack Bender
# 72       The Beginning of the End       Jack Bender
# ...

# %% [markdown]
# # manipulating data frame

# %% [markdown]
# # adding coln

# %%
df["rating"] # it adds xtra coln with "rating " with value "0"
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 116    0
# 117    0
# 118    0
# 119    0
# 120    0
# Name: rating, Length: 121, dtype: int64

# %%
df
# Out:
#      season episode_num_in_season  episode_num_overall               title  \
# 0         1                     1                    1       Pilot: Part 1
# 1         1                     2                    2       Pilot: Part 2
# 2         1                     3                    3         Tabula Rasa
# 3         1                     4                    4           Walkabout
# 4         1                     5                    5        White Rabbit
# ..      ...                   ...                  ...                 ...
# 116       6                    14                  117       The Candidate
# 117       6                    15                  118      Across the Sea
# 118       6                    16                  119  What They Died For
# 119       6                    17                  120             The End
# 120       6                    18                  121      The End Part 2
#
# ...

# %%
# we can also do eith expression

# %%
df["rating"]=df["us_viewers"]+ df["original_air_date"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# ...

# %%
di={"Name":["sathya","Vardhan","Reddy"],"Roll_NO":[1,2,3],"percentage":[95,96,97]}

# %%
di
# Out:
# {'Name': ['sathya', 'Vardhan', 'Reddy'],
#  'Roll_NO': [1, 2, 3],
#  'percentage': [95, 96, 97]}

# %%
df=pd.DataFrame(di)

# %%
df
# Out:
#       Name  Roll_NO  percentage
# 0   sathya        1          95
# 1  Vardhan        2          96
# 2    Reddy        3          97

# %%
df["total"]
df
# Out:
#       Name  Roll_NO  percentage  total
# 0   sathya        1          95      0
# 1  Vardhan        2          96      0
# 2    Reddy        3          97      0

# %%
df["total"]=df["Roll_NO"] + df["percentage"] # addition of roll_no and "percentage " is stored in total
df
# Out:
#       Name  Roll_NO  percentage  total
# 0   sathya        1          95     96
# 1  Vardhan        2          96     98
# 2    Reddy        3          97    100

# %% [markdown]
# # removing the colum

# %%
df["final_result"]="Pass/fail"
df
# Out:
#       Name  Roll_NO  percentage  total final_result
# 0   sathya        1          95     96    Pass/fail
# 1  Vardhan        2          96     98    Pass/fail
# 2    Reddy        3          97    100    Pass/fail

# %%
 #syntax: df.drop(column="coln_name")
df.drop(columns="final_result") # it removes the coln"final_result" 
                                # it will not be  deleted completly from the data frame
# Out:
#       Name  Roll_NO  percentage  total
# 0   sathya        1          95     96
# 1  Vardhan        2          96     98
# 2    Reddy        3          97    100

# %%
df
# Out:
#       Name  Roll_NO  percentage  total final_result
# 0   sathya        1          95     96    Pass/fail
# 1  Vardhan        2          96     98    Pass/fail
# 2    Reddy        3          97    100    Pass/fail

# %%
#to delete coln permanently from data frame
df.drop(columns="final_result",inplace=True)

# %%
df
# Out:
#       Name  Roll_NO  percentage  total
# 0   sathya        1          95     96
# 1  Vardhan        2          96     98
# 2    Reddy        3          97    100

# %%
df
# Out:
#       Name  Roll_NO  percentage  total
# 0   sathya        1          95     96
# 1  Vardhan        2          96     98
# 2    Reddy        3          97    100

# %% [markdown]
# # removing duplicates

# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\User\\Desktop\\Data.csv") 
df=pd.DataFrame(d) #D and F should be captial

# %%
df
# Out:
#      season episode_num_in_season  episode_num_overall               title  \
# 0         1                     1                    1       Pilot: Part 1
# 1         1                     2                    2       Pilot: Part 2
# 2         1                     3                    3         Tabula Rasa
# 3         1                     4                    4           Walkabout
# 4         1                     5                    5        White Rabbit
# ..      ...                   ...                  ...                 ...
# 116       6                    14                  117       The Candidate
# 117       6                    15                  118      Across the Sea
# 118       6                    16                  119  What They Died For
# 119       6                    17                  120             The End
# 120       6                    18                  121      The End Part 2
#
# ...

# %% [markdown]
# # tto check for duplicates

# %%
df.duplicated() #it gives the boolen values 
               # it returns the True if the whole row is repeated
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 116    False
# 117    False
# 118    False
# 119    False
# 120    False
# Length: 121, dtype: bool

# %%
di={"Name":["sathya","sathya","Reddy","ramesh","suresh","john","sam"],"Roll_NO":[1,1,3,4,5,6,7],"percentage":[95,95,97,99,99,99,95]}

# %%
df=pd.DataFrame(di)
df
# Out:
#      Name  Roll_NO  percentage
# 0  sathya        1          95
# 1  sathya        1          95
# 2   Reddy        3          97
# 3  ramesh        4          99
# 4  suresh        5          99
# 5    john        6          99
# 6     sam        7          95

# %%
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %% [markdown]
# # to remove duplicates

# %%
df
# Out:
#      Name  Roll_NO  percentage
# 0  sathya        1          95
# 1  sathya        1          95
# 2   Reddy        3          97
# 3  ramesh        4          99
# 4  suresh        5          99
# 5    john        6          99
# 6     sam        7          95

# %%
df.drop_duplicates()
# Out:
#      Name  Roll_NO  percentage
# 0  sathya        1          95
# 2   Reddy        3          97
# 3  ramesh        4          99
# 4  suresh        5          99
# 5    john        6          99
# 6     sam        7          95

# %%
df
# Out:
#      Name  Roll_NO  percentage
# 0  sathya        1          95
# 1  sathya        1          95
# 2   Reddy        3          97
# 3  ramesh        4          99
# 4  suresh        5          99
# 5    john        6          99
# 6     sam        7          95

# %% [markdown]
# # to  remove duplicates permanently

# %%
df.drop_duplicates(inplace=True) # the duplicates gets removed permanently

# %%
df
# Out:
#      Name  Roll_NO  percentage
# 0  sathya        1          95
# 2   Reddy        3          97
# 3  ramesh        4          99
# 4  suresh        5          99
# 5    john        6          99
# 6     sam        7          95

# %% [markdown]
# # marks with missing data

# %%
di={"Name":["sathya","sathya","Reddy","ramesh","suresh","john","sam"],"Roll_NO":[1,1,3,4,5,6,7],"percentage":[95,"NAn",97,99,99,99,"Nan"]}

# %%
df=pd.DataFrame(di)# dout

# %%
df
# Out:
#      Name  Roll_NO percentage
# 0  sathya        1         95
# 1  sathya        1        NAn
# 2   Reddy        3         97
# 3  ramesh        4         99
# 4  suresh        5         99
# 5    john        6         99
# 6     sam        7        Nan

# %%
df.fillna(100) #DOUT
df
# Out:
#      Name  Roll_NO percentage
# 0  sathya        1         95
# 1  sathya        1        NAn
# 2   Reddy        3         97
# 3  ramesh        4         99
# 4  suresh        5         99
# 5    john        6         99
# 6     sam        7        Nan

# %%
df["percentage"].fillna(80) # its not filling
# Out:
# 0     95
# 1    NAn
# 2     97
# 3     99
# 4     99
# 5     99
# 6    Nan
# Name: percentage, dtype: object

# %%
import pandas as pd

# %%
di={"Name":["sathya","sathya","Reddy","ramesh","suresh","john","sam"],"Roll_NO":[1,1,3,4,5,6,7],"percentage":[9,65,57,49,99,60,95]}

# %%
df=pd.DataFrame(di)

# %%
df
# Out:
#      Name  Roll_NO  percentage
# 0  sathya        1           9
# 1  sathya        1          65
# 2   Reddy        3          57
# 3  ramesh        4          49
# 4  suresh        5          99
# 5    john        6          60
# 6     sam        7          95

# %%
df["Grade"]="Pass/Fail"

# %%
df
# Out:
#      Name  Roll_NO  percentage      Grade
# 0  sathya        1           9  Pass/Fail
# 1  sathya        1          65  Pass/Fail
# 2   Reddy        3          57  Pass/Fail
# 3  ramesh        4          49  Pass/Fail
# 4  suresh        5          99  Pass/Fail
# 5    john        6          60  Pass/Fail
# 6     sam        7          95  Pass/Fail

# %%
df.loc[df["percentage"]>40,["Grade"]]="A"

# %%
df
# Out:
#      Name  Roll_NO  percentage      Grade
# 0  sathya        1           9  Pass/Fail
# 1  sathya        1          65          A
# 2   Reddy        3          57          A
# 3  ramesh        4          49          A
# 4  suresh        5          99          A
# 5    john        6          60          A
# 6     sam        7          95          A

# %%
df.loc[(df["percentage"]>=40)&(df["percentage"]<60),["Grade"]]="pass"

# %%
df
# Out:
#      Name  Roll_NO  percentage      Grade
# 0  sathya        1           9  Pass/Fail
# 1  sathya        1          65          A
# 2   Reddy        3          57       pass
# 3  ramesh        4          49       pass
# 4  suresh        5          99          A
# 5    john        6          60          A
# 6     sam        7          95          A

# %%
df.loc[(df["percentage"]<10),["Grade"]]="Fail"
df
# Out:
#      Name  Roll_NO  percentage Grade
# 0  sathya        1           9  Fail
# 1  sathya        1          65     A
# 2   Reddy        3          57  pass
# 3  ramesh        4          49  pass
# 4  suresh        5          99     A
# 5    john        6          60     A
# 6     sam        7          95     A

# %% [markdown]
# # Export DataFrame

# %%
df.to_excel("C:\\Users\\User\\Desktop\\marks_with_Grade.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2024/152497141.py in <module>
# ----> 1 df.to_excel("C:\\Users\\User\\Desktop\\marks_with_Grade.xlsx")
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2355             inf_rep=inf_rep,
#    2356         )
# -> 2357         formatter.write(
#    2358             excel_writer,
#    2359             sheet_name=sheet_name,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
# ...

# %%
#in order to not to get index values we have give index ="false"

# %%
df.to_excel("C:\\Users\\User\\Desktop\\marks_with_Grade.xlsx",index=False)
